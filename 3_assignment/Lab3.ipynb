# %% [markdown]
# # 1 метод

# %%
# !pip install nistrng
# Out:
# Collecting nistrng
#   Downloading nistrng-1.2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.10/dist-packages (from nistrng) (1.25.2)
# Requirement already satisfied: scipy>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from nistrng) (1.11.4)
# Building wheels for collected packages: nistrng
#   Building wheel for nistrng (setup.py) ... done
#   Created wheel for nistrng: filename=nistrng-1.2.3-py3-none-any.whl size=38080 sha256=fdb18b59bbde89663a34eb0aaae361b3079437717be9826762cfca770a9d8fe4
#   Stored in directory: /root/.cache/pip/wheels/1c/8b/b4/9748dc9b9309d26efb89edfb91f5f04ce89c6716f5ef413482
# Successfully built nistrng
# Installing collected packages: nistrng
# Successfully installed nistrng-1.2.3

# %%
import random
import time
import numpy as np
import scipy.stats as stats
import timeit
from nistrng import *
import matplotlib.pyplot as plt
from math import log

timer = timeit.default_timer

def gen_1(n, a=22695477, c=1, m=2**32):
  res = []
  s = [i for i in range(10000)]
  x = random.choice(s)
  for i in range(n):
    x = (a * x + c) % m
    res.append(x % 5000)
  return res

samples_1 = [gen_1(1000) for _ in range(20)]

def fib_gen(seed1, seed2, modul = 2**31 - 1):
  while True:
    next_seed = (seed1 + seed2) % modul
    seed1, seed2 = seed2, next_seed
    yield next_seed

def gen_2(n, samp_cnt = 20):
  samples = []
  for i in range(samp_cnt):
    seed1, seed2 = i, i + 1
    gen = fib_gen(seed1, seed2)
    sample = [next(gen) % 5000 for _ in range(1000)]
    samples.append(sample)
  return samples


samples_2 = gen_2(1000)

for i, sample in enumerate(samples_1):
    print(f"Sample {i+1} (Method 1): Среднее = {np.mean(sample)}, Отклонение = {np.std(sample)}, Коэффицент вариации = {np.std(sample)/np.mean(sample)}")
for i, sample in enumerate(samples_2):
    print(f"Sample {i+1} (Method 2): Среднее = {np.mean(sample)}, Отклонение = {np.std(sample)}, Коэффицент вариации = {np.std(sample)/np.mean(sample)}")


for i, sample in enumerate(samples_1):
    frequencies, _ = np.histogram(sample, bins=np.arange(5001))
    print(f"Выборка {i+1} (метод 1): Хи-квадрат не отвергается с вероятностью = {stats.chisquare(frequencies)[1]}")
for i, sample in enumerate(samples_2):
    frequencies, _ = np.histogram(sample, bins=np.arange(5001))
    print(f"Выборка {i+1} (метод 2): Хи-квадрат не отвергается с вероятностью = {stats.chisquare(frequencies)[1]}")
for samples in [samples_1[:5], samples_2[:5]]:
    for i, sample in enumerate(samples):
        binary_sequence: np.ndarray = pack_sequence(samples)
        eligible_battery: dict = check_eligibility_all_battery(binary_sequence, SP800_22R1A_BATTERY)
        print(f'Eligible test from NIST-SP800-22r1a for sample {i}:')
        for name in eligible_battery.keys():
            print("-" + name)
        results = run_all_battery(binary_sequence, eligible_battery, False)
        print("Test results:")
        for result, elapsed_time in results:
            if result.passed:
                print("- PASSED - score: " + str(np.round(result.score, 3)) + " - " + result.name + " - elapsed time: " + str(elapsed_time) + " ms")
            else:
                print("- FAILED - score: " + str(np.round(result.score, 3)) + " - " + result.name + " - elapsed time: " + str(elapsed_time) + " ms")
method_1 = []
method_2 = []
method_numpy = []

for n in [1000, 10000, 100000, 1000000]:
    start = timer()
    gen_1(n)
    print(f"Time for generating {n} numbers using Method 1: {timer() - start}")
    method_1.append(timer() - start)

    start = timer()
    gen_2(n)
    print(f"Time for generating {n} numbers using Method 2: {timer() - start}")
    method_2.append(timer() - start)

    start = timer()
    np.random.randint(0, 5000, size=n)
    print(f"Time for generating {n} numbers using numpy: {timer() - start}")
    method_numpy.append(timer() - start)


plt.plot([1000, 10000, 100000, 1000000], method_1, [1000, 10000, 100000, 1000000], method_2, [1000, 10000, 100000, 1000000], method_numpy)
plt.legend(['method_1', 'method_2', 'numpy'])
plt.xticks(range(1000, 1000000, 499000))
plt.show()
# Out:
# Sample 1 (Method 1): Среднее = 2418.612, Отклонение = 1475.8108515172262, Коэффицент вариации = 0.6101891711102179
# Sample 2 (Method 1): Среднее = 2545.004, Отклонение = 1421.8386954869388, Коэффицент вариации = 0.5586783735848505
# Sample 3 (Method 1): Среднее = 2513.436, Отклонение = 1450.81617784749, Коэффицент вариации = 0.5772242371985958
# Sample 4 (Method 1): Среднее = 2565.516, Отклонение = 1448.11292437572, Коэффицент вариации = 0.5644528914946233
# Sample 5 (Method 1): Среднее = 2479.452, Отклонение = 1458.2495478127191, Коэффицент вариации = 0.5881338085241089
# Sample 6 (Method 1): Среднее = 2543.812, Отклонение = 1424.3719151457599, Коэффицент вариации = 0.5599359996516095
# Sample 7 (Method 1): Среднее = 2538.636, Отклонение = 1461.0383894696267, Коэффицент вариации = 0.5755210236794983
# Sample 8 (Method 1): Среднее = 2525.692, Отклонение = 1428.5305278978115, Коэффицент вариации = 0.5655996566080945
# Sample 9 (Method 1): Среднее = 2544.012, Отклонение = 1417.5267968740486, Коэффицент вариации = 0.5572013012808307
# Sample 10 (Method 1): Среднее = 2491.228, Отклонение = 1424.3261340072365, Коэффицент вариации = 0.5717365628546389
# Sample 11 (Method 1): Среднее = 2534.58, Отклонение = 1447.1853715402185, Коэффицент вариации = 0.5709764030096578
# Sample 12 (Method 1): Среднее = 2526.26, Отклонение = 1421.6612846947758, Коэффицент вариации = 0.5627533526615534
# Sample 13 (Method 1): Среднее = 2509.1, Отклонение = 1435.2718606591575, Коэффицент вариации = 0.5720265675577528
# Sample 14 (Method 1): Среднее = 2441.164, Отклонение = 1467.6979256999718, Коэффицент вариации = 0.6012287276479465
# Sample 15 (Method 1): Среднее = 2555.076, Отклонение = 1471.644361326472, Коэффицент вариации = 0.5759689188605239
# Sample 16 (Method 1): Среднее = 2492.204, Отклонение = 1440.1973595254228, Коэффицент вариации = 0.5778810079453458
# Sample 17 (Method 1): Среднее = 2438.524, Отклонение = 1443.7531733035255, Коэффицент вариации = 0.5920602681390569
# Sample 18 (Method 1): Среднее = 2503.308, Отклонение = 1449.8960780469752, Коэффицент вариации = 0.5791920443057647
# Sample 19 (Method 1): Среднее = 2471.428, Отклонение = 1451.3542382258026, Коэффицент вариации = 0.5872532957568671
# Sample 20 (Method 1): Среднее = 2555.596, Отклонение = 1426.0827327977854, Коэффицент вариации = 0.5580235423743758
# Sample 1 (Method 2): Среднее = 2431.763, Отклонение = 1450.098601761618, Коэффицент вариации = 0.5963157601138014
# Sample 2 (Method 2): Среднее = 2438.111, Отклонение = 1447.4935269903626, Коэффицент вариации = 0.5936946787863074
# Sample 3 (Method 2): Среднее = 2440.812, Отклонение = 1445.4657196405594, Коэффицент вариации = 0.5922069047679869
# Sample 4 (Method 2): Среднее = 2500.278, Отклонение = 1432.8589158448226, Коэффицент вариации = 0.5730798398597367
# Sample 5 (Method 2): Среднее = 2443.096, Отклонение = 1455.1748076379004, Коэффицент вариации = 0.5956273546507793
# Sample 6 (Method 2): Среднее = 2556.443, Отклонение = 1467.2639110776902, Коэффицент вариации = 0.5739474383264912
# Sample 7 (Method 2): Среднее = 2505.146, Отклонение = 1461.5946957635006, Коэффицент вариации = 0.5834369317251371
# Sample 8 (Method 2): Среднее = 2552.14, Отклонение = 1436.7696267669357, Коэффицент вариации = 0.5629666189029348
# Sample 9 (Method 2): Среднее = 2490.665, Отклонение = 1461.3685040998384, Коэффицент вариации = 0.586738282386366
# Sample 10 (Method 2): Среднее = 2439.836, Отклонение = 1488.976460896545, Коэффицент вариации = 0.610277273102186
# Sample 11 (Method 2): Среднее = 2504.831, Отклонение = 1484.5786885305204, Коэффицент вариации = 0.5926861686598898
# Sample 12 (Method 2): Среднее = 2447.532, Отклонение = 1435.156118676989, Коэффицент вариации = 0.5863686843224069
# Sample 13 (Method 2): Среднее = 2465.762, Отклонение = 1454.3552768687575, Коэффицент вариации = 0.5898198110234311
# Sample 14 (Method 2): Среднее = 2522.817, Отклонение = 1440.329977300688, Коэффицент вариации = 0.570921306341557
# Sample 15 (Method 2): Среднее = 2454.165, Отклонение = 1445.5547010663415, Коэффицент вариации = 0.5890209912806765
# Sample 16 (Method 2): Среднее = 2409.984, Отклонение = 1455.1642951034773, Коэффицент вариации = 0.6038066207507923
# Sample 17 (Method 2): Среднее = 2436.744, Отклонение = 1408.6729898965195, Коэффицент вариации = 0.5780964228891173
# Sample 18 (Method 2): Среднее = 2513.855, Отклонение = 1431.696557226775, Коэффицент вариации = 0.5695223301370902
# Sample 19 (Method 2): Среднее = 2474.44, Отклонение = 1454.8391740670168, Коэффицент вариации = 0.5879468380995363
# Sample 20 (Method 2): Среднее = 2480.259, Отклонение = 1441.497839026823, Коэффицент вариации = 0.5811884319447376
# Выборка 1 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.5728327458205538
# Выборка 2 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.26952250642278247
# Выборка 3 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.08019682422960783
# Выборка 4 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.7209689966615751
# Выборка 5 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.971795414383142
# Выборка 6 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.5728327458205538
# Выборка 7 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.8835682779415188
# Выборка 8 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.9330025728476989
# Выборка 9 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.7845356663693589
# Выборка 10 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.6496538896253599
# Выборка 11 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.8389210217650919
# Выборка 12 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.9866663542708273
# Выборка 13 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.13378962737054145
# Выборка 14 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.26952250642278247
# Выборка 15 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.9022906496643158
# Выборка 16 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.23780023266685987
# Выборка 17 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.3759798448063327
# Выборка 18 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.862463593270617
# Выборка 19 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.9330025728476989
# Выборка 20 (метод 1): Хи-квадрат не отвергается с вероятностью = 0.5728327458205538
# Выборка 1 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.493350889587423
# Выборка 2 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.493350889587423
# Выборка 3 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.493350889587423
# Выборка 4 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.7209689966615751
# Выборка 5 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.493350889587423
# Выборка 6 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.044782213213764244
# Выборка 7 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.41434082792343546
# Выборка 8 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.611764583937915
# Выборка 9 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.15623959248839922
# Выборка 10 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.15623959248839922
# Выборка 11 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.11368775871381896
# Выборка 12 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.8835682779415188
# Выборка 13 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.0021028998260098734
# Выборка 14 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.3388556855869116
# Выборка 15 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.6861570433929784
# Выборка 16 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.3032805334571884
# Выборка 17 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.493350889587423
# Выборка 18 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.11368775871381896
# Выборка 19 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.5332311391079753
# Выборка 20 (метод 2): Хи-квадрат не отвергается с вероятностью = 0.13378962737054145
# Eligible test from NIST-SP800-22r1a for sample 0:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.889 - Monobit - elapsed time: 1 ms
# - PASSED - score: 1.0 - Frequency Within Block - elapsed time: 0 ms
# - PASSED - score: 0.379 - Runs - elapsed time: 31 ms
# - PASSED - score: 0.279 - Longest Run Ones In A Block - elapsed time: 21 ms
# - FAILED - score: 0.0 - Binary Matrix Rank - elapsed time: 546 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 3 ms
# - PASSED - score: 0.381 - Non Overlapping Template Matching - elapsed time: 424 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 7333 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 8625 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 193 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 467 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Eligible test from NIST-SP800-22r1a for sample 1:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.889 - Monobit - elapsed time: 19 ms
# - PASSED - score: 1.0 - Frequency Within Block - elapsed time: 0 ms
# - PASSED - score: 0.379 - Runs - elapsed time: 59 ms
# - PASSED - score: 0.279 - Longest Run Ones In A Block - elapsed time: 94 ms
# - FAILED - score: 0.0 - Binary Matrix Rank - elapsed time: 1341 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 7 ms
# - PASSED - score: 0.325 - Non Overlapping Template Matching - elapsed time: 406 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 6197 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 3442 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 54 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 150 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 0 ms
# Eligible test from NIST-SP800-22r1a for sample 2:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.889 - Monobit - elapsed time: 0 ms
# - PASSED - score: 1.0 - Frequency Within Block - elapsed time: 0 ms
# - PASSED - score: 0.379 - Runs - elapsed time: 19 ms
# - PASSED - score: 0.279 - Longest Run Ones In A Block - elapsed time: 17 ms
# - FAILED - score: 0.0 - Binary Matrix Rank - elapsed time: 269 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 2 ms
# - PASSED - score: 0.477 - Non Overlapping Template Matching - elapsed time: 183 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 2099 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1993 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 48 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 115 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Eligible test from NIST-SP800-22r1a for sample 3:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.889 - Monobit - elapsed time: 0 ms
# - PASSED - score: 1.0 - Frequency Within Block - elapsed time: 0 ms
# - PASSED - score: 0.379 - Runs - elapsed time: 16 ms
# - PASSED - score: 0.279 - Longest Run Ones In A Block - elapsed time: 10 ms
# - FAILED - score: 0.0 - Binary Matrix Rank - elapsed time: 211 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 2 ms
# - PASSED - score: 0.528 - Non Overlapping Template Matching - elapsed time: 130 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 1701 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1752 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 47 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 114 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 0 ms
# Eligible test from NIST-SP800-22r1a for sample 4:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.889 - Monobit - elapsed time: 0 ms
# - PASSED - score: 1.0 - Frequency Within Block - elapsed time: 1 ms
# - PASSED - score: 0.379 - Runs - elapsed time: 15 ms
# - PASSED - score: 0.279 - Longest Run Ones In A Block - elapsed time: 9 ms
# - FAILED - score: 0.0 - Binary Matrix Rank - elapsed time: 241 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 2 ms
# - PASSED - score: 0.485 - Non Overlapping Template Matching - elapsed time: 239 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 3517 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1691 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 41 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 118 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 0 ms
# Eligible test from NIST-SP800-22r1a for sample 0:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.39 - Monobit - elapsed time: 0 ms
# - PASSED - score: 0.523 - Frequency Within Block - elapsed time: 1 ms
# - FAILED - score: 0.0 - Runs - elapsed time: 11 ms
# - PASSED - score: 0.768 - Longest Run Ones In A Block - elapsed time: 10 ms
# - PASSED - score: 0.529 - Binary Matrix Rank - elapsed time: 257 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 1 ms
# - PASSED - score: 0.984 - Non Overlapping Template Matching - elapsed time: 171 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 1620 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1716 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 42 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 114 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Eligible test from NIST-SP800-22r1a for sample 1:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.39 - Monobit - elapsed time: 0 ms
# - PASSED - score: 0.523 - Frequency Within Block - elapsed time: 0 ms
# - FAILED - score: 0.0 - Runs - elapsed time: 12 ms
# - PASSED - score: 0.768 - Longest Run Ones In A Block - elapsed time: 9 ms
# - PASSED - score: 0.529 - Binary Matrix Rank - elapsed time: 266 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 1 ms
# - PASSED - score: 0.282 - Non Overlapping Template Matching - elapsed time: 137 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 1677 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1844 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 79 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 224 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Eligible test from NIST-SP800-22r1a for sample 2:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.39 - Monobit - elapsed time: 0 ms
# - PASSED - score: 0.523 - Frequency Within Block - elapsed time: 1 ms
# - FAILED - score: 0.0 - Runs - elapsed time: 26 ms
# - PASSED - score: 0.768 - Longest Run Ones In A Block - elapsed time: 23 ms
# - PASSED - score: 0.529 - Binary Matrix Rank - elapsed time: 426 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 1 ms
# - PASSED - score: 0.063 - Non Overlapping Template Matching - elapsed time: 227 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 2427 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1717 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 41 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 122 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Eligible test from NIST-SP800-22r1a for sample 3:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.39 - Monobit - elapsed time: 2 ms
# - PASSED - score: 0.523 - Frequency Within Block - elapsed time: 0 ms
# - FAILED - score: 0.0 - Runs - elapsed time: 11 ms
# - PASSED - score: 0.768 - Longest Run Ones In A Block - elapsed time: 10 ms
# - PASSED - score: 0.529 - Binary Matrix Rank - elapsed time: 234 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 2 ms
# - PASSED - score: 0.49 - Non Overlapping Template Matching - elapsed time: 149 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 1649 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 1706 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 42 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 123 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Eligible test from NIST-SP800-22r1a for sample 4:
# -monobit
# -frequency_within_block
# -runs
# -longest_run_ones_in_a_block
# -binary_matrix_rank
# -dft
# -non_overlapping_template_matching
# -serial
# -approximate_entropy
# -cumulative sums
# -random_excursion
# -random_excursion_variant
# Test results:
# - PASSED - score: 0.39 - Monobit - elapsed time: 1 ms
# - PASSED - score: 0.523 - Frequency Within Block - elapsed time: 0 ms
# - FAILED - score: 0.0 - Runs - elapsed time: 11 ms
# - PASSED - score: 0.768 - Longest Run Ones In A Block - elapsed time: 10 ms
# - PASSED - score: 0.529 - Binary Matrix Rank - elapsed time: 226 ms
# - FAILED - score: 0.0 - Discrete Fourier Transform - elapsed time: 1 ms
# - FAILED - score: 0.0 - Non Overlapping Template Matching - elapsed time: 131 ms
# - FAILED - score: 0.0 - Serial - elapsed time: 1672 ms
# - FAILED - score: 0.0 - Approximate Entropy - elapsed time: 2064 ms
# - FAILED - score: 0.0 - Cumulative Sums - elapsed time: 85 ms
# - FAILED - score: 0.683 - Random Excursion - elapsed time: 222 ms
# - PASSED - score: 0.17 - Random Excursion Variant - elapsed time: 1 ms
# Time for generating 1000 numbers using Method 1: 0.0014962850000017625
# Time for generating 1000 numbers using Method 2: 0.01320306000002347
# Time for generating 1000 numbers using numpy: 0.00027744900000925554
# Time for generating 10000 numbers using Method 1: 0.007631672000002254
# Time for generating 10000 numbers using Method 2: 0.013739514999997482
# Time for generating 10000 numbers using numpy: 0.00030435100001113824
# Time for generating 100000 numbers using Method 1: 0.0721848009999917
# Time for generating 100000 numbers using Method 2: 0.01967764799999827
# Time for generating 100000 numbers using numpy: 0.0020884209999962877
# Time for generating 1000000 numbers using Method 1: 0.7007316329999753
# Time for generating 1000000 numbers using Method 2: 0.014615829999996777
# Time for generating 1000000 numbers using numpy: 0.020802264999986164
